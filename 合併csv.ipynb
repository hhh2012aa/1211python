# %%
import pandas as pd

# %%
df1 = pd.read_csv("LoanStats3a_securev1.csv", skiprows=1)
df2 = pd.read_csv("LoanStats3b_securev1.csv", skiprows=1)
df3 = pd.read_csv("LoanStats3c_securev1.csv", skiprows=1)
df4 = pd.read_csv("LoanStats3d_securev1.csv", skiprows=1)

# %%
df4["loan_status"]
# Out:
# 0          Fully Paid
# 1          Fully Paid
# 2          Fully Paid
# 3          Fully Paid
# 4          Fully Paid
# 5          Fully Paid
# 6         Charged Off
# 7          Fully Paid
# 8          Fully Paid
# 9          Fully Paid
# 10         Fully Paid
# 11         Fully Paid
# 12         Fully Paid
# 13         Fully Paid
# 14         Fully Paid
# 15        Charged Off
# 16         Fully Paid
# 17         Fully Paid
# 18         Fully Paid
# 19         Fully Paid
# 20            Current
# 21         Fully Paid
# 22            Current
# 23         Fully Paid
# 24         Fully Paid
# 25         Fully Paid
# 26        Charged Off
# 27         Fully Paid
# 28         Fully Paid
# 29         Fully Paid
#              ...
# 421067     Fully Paid
# 421068    Charged Off
# 421069     Fully Paid
# 421070        Current
# 421071        Current
# 421072     Fully Paid
# 421073     Fully Paid
# 421074        Current
# 421075     Fully Paid
# 421076    Charged Off
# ...

# %%
frames = [df1, df2, df3, df4]
df5 = pd.concat(frames)

# %%
df5.to_csv("new.csv")

# %%
df5
# Out:
#                                                       id  member_id  \
# 0                                                1077501        NaN
# 1                                                1077430        NaN
# 2                                                1077175        NaN
# 3                                                1076863        NaN
# 4                                                1075358        NaN
# 5                                                1075269        NaN
# 6                                                1069639        NaN
# 7                                                1072053        NaN
# 8                                                1071795        NaN
# 9                                                1071570        NaN
# 10                                               1070078        NaN
# 11                                               1069908        NaN
# 12                                               1064687        NaN
# ...
